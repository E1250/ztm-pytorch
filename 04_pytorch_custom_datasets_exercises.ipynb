# %% [markdown]
# <a href="https://colab.research.google.com/github/E1250/ztm-pytorch/blob/main/04_pytorch_custom_datasets_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook Solutions - https://github.com/mrdbourke/pytorch-deep-learning/blob/main/extras/solutions/04_pytorch_custom_datasets_exercise_solutions.ipynb

# %% [markdown]
# # 04. PyTorch Custom Datasets Exercises Template
#
# Welcome to the 04. PyTorch Custom Datasets exercise template.
#
# The best way to practice PyTorch code is to write more PyTorch code.
#
# So read the original notebook and try to complete the exercises by writing code where it's required.
#
# Feel free to reference the original resources whenever you need but should practice writing all of the code yourself.
#
# ## Resources
#
# 1. These exercises/solutions are based on [notebook 04 of the Learn PyTorch for Deep Learning course](https://www.learnpytorch.io/04_pytorch_custom_datasets/).
# 2. See a live [walkthrough of the solutions (errors and all) on YouTube](https://youtu.be/vsFMF9wqWx0).
# 3. See [other solutions on the course GitHub](https://github.com/mrdbourke/pytorch-deep-learning/tree/main/extras/solutions).

# %%
# Check for GPU
# !nvidia-smi
# Out:
# Mon Jul 24 13:02:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Import torch
import torch
from torch import nn

# Exercises require PyTorch > 1.10.0
print(torch.__version__)

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 2.0.1+cu118
# 'cuda'

# %% [markdown]
# ## 1. Our models are underperforming (not fitting the data well). What are 3 methods for preventing underfitting? Write them down and explain each with a sentence.

# %% [markdown]
# * Train for Longer time
# * Add more layers
# * Change learning rate
# * Use less reglarization
# * Use Transfer learning

# %% [markdown]
# ## 2. Recreate the data loading functions we built in [sections 1, 2, 3 and 4 of notebook 04](https://www.learnpytorch.io/04_pytorch_custom_datasets/). You should have train and test `DataLoader`'s ready to use.

# %%
# 1. Get data
import requests
import zipfile
from pathlib import Path

data_path = Path('pizza_steak_sushi')
data_path.mkdir(parents = True , exist_ok = True)

DATA_LINK = 'https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip'
with open('pizza_steak_sushi.zip','wb') as f:
  print('Downloading Data...')
  data_body = requests.get(DATA_LINK)
  f.write(data_body.content)

with zipfile.ZipFile("pizza_steak_sushi.zip","r") as zip_ref:
  print('UnZipping File...')
  zip_ref.extractall('pizza_steak_sushi')
# Out:
# Downloading Data...
# UnZipping File...

# %%
# %rm -rf content

# %%
# 2. Become one with the data
import os
def walk_through_dir(dir_path):
  """Walks through dir_path returning file counts of its contents."""
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
# Setup train and testing paths
train_path = data_path / "train"
test_path = data_path / "test"

# %%
# Visualize an image
import random
from PIL import Image

images_path = list(data_path.glob('*/*/*.jpg'))

random_image_path = random.choice(images_path)

img_class = random_image_path.parent.stem

img = Image.open(random_image_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7B469C52F040>

# %%
# Do the image visualization with matplotlib
import numpy as np
import matplotlib.pyplot as plt

img_as_array = np.asarray(img)

plt.imshow(img_as_array)
plt.axis('off')
plt.title(img_class);

# %% [markdown]
# We've got some images in our folders.
#
# Now we need to make them compatible with PyTorch by:
# 1. Transform the data into tensors.
# 2. Turn the tensor data into a `torch.utils.data.Dataset` and later a `torch.utils.data.DataLoader`.

# %%
# 3.1 Transforming data with torchvision.transforms
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# Write transform for turning images into tensors
transformer = transforms.Compose([
    transforms.Resize(size =  (64,64)),
    transforms.RandomHorizontalFlip(0.5),
    transforms.ToTensor()
])

# %%
# Write a function to plot transformed images
def plot_transformed_images(images_path, transformer, num_of_images=3, seed=42):
  random_images_path = random.sample(images_path , k = num_of_images)

  for image_path in random_images_path:
    with Image.open(image_path) as f:
      fig , ax = plt.subplots(1,2)

      ax[0].imshow(f)
      ax[0].axis('off')
      ax[0].set_title('Original')

      ax[1].imshow(f)
      ax[1].axis('off')
      ax[1].set_title('Transformed')

# %%
plot_transformed_images(images_path,
                        transformer=transformer,
                        num_of_images=3)

# %% [markdown]
# ### Load image data using `ImageFolder`

# %%
# Use ImageFolder to create dataset(s)
train_data = datasets.ImageFolder(train_path , transform = transformer , target_transform = None)
test_data = datasets.ImageFolder(test_path , transform = transformer )

# %%
# Get class names as a list
class_names = train_data.classes
class_names
# Out:
# ['pizza', 'steak', 'sushi']

# %%
# Can also get class names as a dict
class_dict = train_data.class_to_idx
class_dict
# Out:
# {'pizza': 0, 'steak': 1, 'sushi': 2}

# %%
# Check the lengths of each dataset
len(train_data), len(test_data)
# Out:
# (225, 75)

# %%
# Turn train and test Datasets into DataLoaders
train_dataloader = DataLoader(
    train_data,
    batch_size = 1,
    shuffle = True
)

test_dataloader = DataLoader(
    test_data,
    batch_size = 1,
)

# %%
# How many batches of images are in our data loaders?
len(train_dataloader) , len(test_dataloader)
# Out:
# (225, 75)

# %% [markdown]
# ## 3. Recreate `model_0` we built in section 7 of notebook 04.

# %%
class TinyVGG(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int) -> None:
        super().__init__()
        self.conv_block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2)
        )
        self.conv_block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=hidden_units*16*16,
                      out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        return self.classifier(self.conv_block_2(self.conv_block_1(x)))

torch.manual_seed(42)
model = TinyVGG(input_shape=3,
                  hidden_units=10,
                  output_shape=len(train_data.classes)).to(device)
model
# Out:
# TinyVGG(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2560, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ## 4. Create training and testing functions for `model_0`.

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):

  # Put the model in train mode
  model.train()

  # Setup train loss and train accuracy values
  train_loss, train_acc = 0, 0

  # Loop through data loader and data batches
  for batch ,(X,y) in enumerate(dataloader):
    # Send data to target device
    X , y = X.to(device) , y.to(device)

    # 1. Forward pass
    y_pred = model(X)
    # 2. Calculate and accumulate loss
    loss = loss_fn(y_pred , y)
    train_loss += loss.item()

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Loss backward
    loss.backward()

    # 5. Optimizer step
    optimizer.step()

    # Calculate and accumualte accuracy metric across all batches
    y_pred_class = torch.argmax(torch.softmax(y_pred , dim = 1) , dim = 1)
    train_acc += (y_pred_class == y).sum().item()/len(y_pred)


  # Adjust metrics to get average loss and average accuracy per batch
  train_loss = train_loss / len(dataloader)
  train_acc = train_acc / len(dataloader)
  return train_loss , train_acc

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):

  # Put model in eval mode
  model.eval()

  # Setup the test loss and test accuracy values
  test_loss, test_acc = 0, 0

  # Turn on inference context manager
  with torch.inference_mode():
    # Loop through DataLoader batches
    for batch , (X,y) in enumerate(dataloader):
      # Send data to target device
      X , y = X.to(device) , y.to(device)

      # 1. Forward pass
      test_pred_logits = model(X)

      # 2. Calculuate and accumulate loss
      loss = loss_fn(test_pred_logits , y)
      test_loss += loss.item()

      # Calculate and accumulate accuracy
      test_pred_labels = test_pred_logits.argmax(dim=1)
      test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))


  # Adjust metrics to get average loss and accuracy per batch
  test_loss = test_loss / len(dataloader)
  test_acc = test_acc / len(dataloader)
  return test_loss, test_acc

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

  # Create results dictionary
  results = {"train_loss": [],
             "train_acc": [],
             "test_loss": [],
             "test_acc": []}

  # Loop through the training and testing steps for a number of epochs
  for epoch in tqdm(range(epochs)):
    # Train step
    train_loss, train_acc = train_step(model=model,
                                       dataloader=train_dataloader,
                                       loss_fn=loss_fn,
                                       optimizer=optimizer)
    # Test step
    test_loss, test_acc = test_step(model=model,
                                    dataloader=test_dataloader,
                                    loss_fn=loss_fn)

    # Print out what's happening
    print(f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
    )

    # Update the results dictionary
    results["train_loss"].append(train_loss)
    results["train_acc"].append(train_acc)
    results["test_loss"].append(test_loss)
    results["test_acc"].append(test_acc)

  # Return the results dictionary
  return results

# %% [markdown]
# ## 5. Try training the model you made in exercise 3 for 5, 20 and 50 epochs, what happens to the results?
# * Use `torch.optim.Adam()` with a learning rate of 0.001 as the optimizer.

# %%
# Train for 5 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params = model.parameters(),
                             lr=0.001)

model_0_results = train(model=model,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=5)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1035 | train_acc: 0.2978 | test_loss: 1.0988 | test_acc: 0.2400
# Epoch: 2 | train_loss: 1.0992 | train_acc: 0.3111 | test_loss: 1.0998 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.0994 | train_acc: 0.3333 | test_loss: 1.0998 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.0988 | train_acc: 0.3467 | test_loss: 1.1004 | test_acc: 0.3333
# Epoch: 5 | train_loss: 1.0988 | train_acc: 0.3200 | test_loss: 1.1019 | test_acc: 0.3333

# %%
# Train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params = model.parameters(),
                             lr=0.001)

model_0_results = train(model=model,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0984 | train_acc: 0.3689 | test_loss: 1.1001 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.0989 | train_acc: 0.3378 | test_loss: 1.1013 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.0999 | train_acc: 0.3422 | test_loss: 1.1021 | test_acc: 0.3333
# Epoch: 4 | train_loss: 1.0921 | train_acc: 0.3600 | test_loss: 1.0569 | test_acc: 0.3600
# Epoch: 5 | train_loss: 1.0595 | train_acc: 0.4578 | test_loss: 1.0595 | test_acc: 0.3600
# Epoch: 6 | train_loss: 0.9648 | train_acc: 0.5422 | test_loss: 1.0889 | test_acc: 0.4533
# Epoch: 7 | train_loss: 0.8567 | train_acc: 0.6178 | test_loss: 1.0224 | test_acc: 0.3733
# Epoch: 8 | train_loss: 0.7864 | train_acc: 0.6444 | test_loss: 1.1100 | test_acc: 0.4000
# Epoch: 9 | train_loss: 0.7606 | train_acc: 0.6756 | test_loss: 1.0877 | test_acc: 0.4133
# Epoch: 10 | train_loss: 0.6934 | train_acc: 0.7111 | test_loss: 1.1975 | test_acc: 0.5333
# Epoch: 11 | train_loss: 0.6001 | train_acc: 0.7556 | test_loss: 1.2998 | test_acc: 0.4800
# Epoch: 12 | train_loss: 0.5311 | train_acc: 0.7867 | test_loss: 1.5276 | test_acc: 0.4667
# Epoch: 13 | train_loss: 0.5198 | train_acc: 0.7822 | test_loss: 1.6109 | test_acc: 0.5467
# Epoch: 14 | train_loss: 0.3885 | train_acc: 0.8444 | test_loss: 1.7702 | test_acc: 0.5067
# Epoch: 15 | train_loss: 0.4521 | train_acc: 0.8533 | test_loss: 2.0109 | test_acc: 0.5067
# Epoch: 16 | train_loss: 0.3098 | train_acc: 0.8844 | test_loss: 1.9143 | test_acc: 0.5333
# Epoch: 17 | train_loss: 0.3133 | train_acc: 0.8933 | test_loss: 2.1695 | test_acc: 0.5067
# Epoch: 18 | train_loss: 0.2469 | train_acc: 0.8844 | test_loss: 2.3635 | test_acc: 0.5067
# Epoch: 19 | train_loss: 0.1936 | train_acc: 0.9333 | test_loss: 2.9734 | test_acc: 0.4267
# Epoch: 20 | train_loss: 0.1922 | train_acc: 0.9200 | test_loss: 2.7907 | test_acc: 0.4133

# %%
# Train for 50 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params = model.parameters(),
                             lr=0.001)

model_0_results = train(model=model,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=50)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.1573 | train_acc: 0.9289 | test_loss: 3.5460 | test_acc: 0.5200
# Epoch: 2 | train_loss: 0.1214 | train_acc: 0.9467 | test_loss: 3.3287 | test_acc: 0.4267
# Epoch: 3 | train_loss: 0.1182 | train_acc: 0.9467 | test_loss: 3.5146 | test_acc: 0.4667
# Epoch: 4 | train_loss: 0.1108 | train_acc: 0.9733 | test_loss: 4.2478 | test_acc: 0.4400
# Epoch: 5 | train_loss: 0.0874 | train_acc: 0.9689 | test_loss: 3.4774 | test_acc: 0.5200
# Epoch: 6 | train_loss: 0.1047 | train_acc: 0.9778 | test_loss: 3.6035 | test_acc: 0.4667
# Epoch: 7 | train_loss: 0.0731 | train_acc: 0.9822 | test_loss: 4.3704 | test_acc: 0.5067
# Epoch: 8 | train_loss: 0.0658 | train_acc: 0.9822 | test_loss: 4.3427 | test_acc: 0.4933
# Epoch: 9 | train_loss: 0.0438 | train_acc: 0.9867 | test_loss: 5.1737 | test_acc: 0.4800
# Epoch: 10 | train_loss: 0.0306 | train_acc: 0.9956 | test_loss: 5.4905 | test_acc: 0.4800
# Epoch: 11 | train_loss: 0.1016 | train_acc: 0.9689 | test_loss: 6.1184 | test_acc: 0.4000
# Epoch: 12 | train_loss: 0.0732 | train_acc: 0.9689 | test_loss: 5.6641 | test_acc: 0.5067
# Epoch: 13 | train_loss: 0.0660 | train_acc: 0.9822 | test_loss: 4.4489 | test_acc: 0.4933
# Epoch: 14 | train_loss: 0.1149 | train_acc: 0.9556 | test_loss: 4.4123 | test_acc: 0.5467
# Epoch: 15 | train_loss: 0.1183 | train_acc: 0.9556 | test_loss: 5.1103 | test_acc: 0.4400
# Epoch: 16 | train_loss: 0.0610 | train_acc: 0.9689 | test_loss: 4.2208 | test_acc: 0.5067
# Epoch: 17 | train_loss: 0.0185 | train_acc: 0.9956 | test_loss: 4.9307 | test_acc: 0.4667
# Epoch: 18 | train_loss: 0.0083 | train_acc: 1.0000 | test_loss: 5.4336 | test_acc: 0.5333
# Epoch: 19 | train_loss: 0.0051 | train_acc: 1.0000 | test_loss: 5.6871 | test_acc: 0.4933
# Epoch: 20 | train_loss: 0.0032 | train_acc: 1.0000 | test_loss: 5.5166 | test_acc: 0.5067
# Epoch: 21 | train_loss: 0.0029 | train_acc: 1.0000 | test_loss: 5.8336 | test_acc: 0.5867
# Epoch: 22 | train_loss: 0.0017 | train_acc: 1.0000 | test_loss: 5.4902 | test_acc: 0.5467
# Epoch: 23 | train_loss: 0.0013 | train_acc: 1.0000 | test_loss: 6.1293 | test_acc: 0.5333
# Epoch: 24 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 5.8012 | test_acc: 0.5333
# Epoch: 25 | train_loss: 0.0010 | train_acc: 1.0000 | test_loss: 6.5043 | test_acc: 0.5733
# Epoch: 26 | train_loss: 0.0010 | train_acc: 1.0000 | test_loss: 7.3068 | test_acc: 0.4933
# Epoch: 27 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 6.6544 | test_acc: 0.4800
# Epoch: 28 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 6.8041 | test_acc: 0.5467
# Epoch: 29 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 6.4052 | test_acc: 0.5333
# Epoch: 30 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 7.2249 | test_acc: 0.4933
# Epoch: 31 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 7.3718 | test_acc: 0.5200
# Epoch: 32 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 6.7075 | test_acc: 0.5467
# Epoch: 33 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 7.3458 | test_acc: 0.5467
# Epoch: 34 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 7.9576 | test_acc: 0.4667
# Epoch: 35 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 7.6445 | test_acc: 0.5067
# Epoch: 36 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 7.8080 | test_acc: 0.5600
# Epoch: 37 | train_loss: 0.0002 | train_acc: 1.0000 | test_loss: 8.4168 | test_acc: 0.4800
# Epoch: 38 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 8.1424 | test_acc: 0.4800
# Epoch: 39 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 8.2700 | test_acc: 0.4800
# Epoch: 40 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 7.9718 | test_acc: 0.5067
# Epoch: 41 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 8.8974 | test_acc: 0.5200
# Epoch: 42 | train_loss: 0.0001 | train_acc: 1.0000 | test_loss: 8.0553 | test_acc: 0.4933
# Epoch: 43 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 8.7375 | test_acc: 0.5200
# Epoch: 44 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 7.5965 | test_acc: 0.5600
# Epoch: 45 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 7.9529 | test_acc: 0.4933
# Epoch: 46 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 8.8062 | test_acc: 0.4800
# Epoch: 47 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 8.8556 | test_acc: 0.5067
# Epoch: 48 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 9.1957 | test_acc: 0.5067
# Epoch: 49 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 7.7267 | test_acc: 0.5733
# Epoch: 50 | train_loss: 0.0000 | train_acc: 1.0000 | test_loss: 9.0158 | test_acc: 0.5200

# %% [markdown]
# It looks like our model is starting to overfit towards the end (performing far better on the training data than on the testing data).
#
# In order to fix this, we'd have to introduce ways of preventing overfitting.

# %% [markdown]
# ## 6. Double the number of hidden units in your model and train it for 20 epochs, what happens to the results?

# %%
# Double the number of hidden units and train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %% [markdown]
# It looks like the model is still overfitting, even when changing the number of hidden units.
#
# To fix this, we'd have to look at ways to prevent overfitting with our model.

# %% [markdown]
# ## 7. Double the data you're using with your model from step 6 and train it for 20 epochs, what happens to the results?
# * **Note:** You can use the [custom data creation notebook](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/extras/04_custom_data_creation.ipynb) to scale up your Food101 dataset.
# * You can also find the [already formatted double data (20% instead of 10% subset) dataset on GitHub](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/data/pizza_steak_sushi_20_percent.zip), you will need to write download code like in exercise 2 to get it into this notebook.

# %%
# 1. Get data
import requests
import zipfile
from pathlib import Path

data_path = Path('pizza_steak_sushi_20_percent')
data_path.mkdir(parents = True , exist_ok = True)

DATA_LINK = 'https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi_20_percent.zip'
with open('pizza_steak_sushi_20_percent.zip','wb') as f:
  print('Downloading Data...')
  data_body = requests.get(DATA_LINK)
  f.write(data_body.content)

with zipfile.ZipFile("pizza_steak_sushi_20_percent.zip","r") as zip_ref:
  print('UnZipping File...')
  zip_ref.extractall('pizza_steak_sushi_20_percent')
# Out:
# Downloading Data...
# UnZipping File...

# %%
# See how many images we have
walk_through_dir(data_path)
# Out:
# There are 2 directories and 0 images in 'pizza_steak_sushi_20_percent'.
# There are 3 directories and 0 images in 'pizza_steak_sushi_20_percent/test'.
# There are 0 directories and 58 images in 'pizza_steak_sushi_20_percent/test/steak'.
# There are 0 directories and 46 images in 'pizza_steak_sushi_20_percent/test/pizza'.
# There are 0 directories and 46 images in 'pizza_steak_sushi_20_percent/test/sushi'.
# There are 3 directories and 0 images in 'pizza_steak_sushi_20_percent/train'.
# There are 0 directories and 146 images in 'pizza_steak_sushi_20_percent/train/steak'.
# There are 0 directories and 154 images in 'pizza_steak_sushi_20_percent/train/pizza'.
# There are 0 directories and 150 images in 'pizza_steak_sushi_20_percent/train/sushi'.

# %% [markdown]
# Excellent, we now have double the training and testing images...

# %%
# Create the train and test paths

train_data_20_percent_path = data_path / "train"
test_data_20_percent_path = data_path / "test"

train_data_20_percent_path, test_data_20_percent_path
# Out:
# (PosixPath('pizza_steak_sushi_20_percent/train'),
#  PosixPath('pizza_steak_sushi_20_percent/test'))

# %%
# Turn the 20 percent datapaths into Datasets and DataLoaders
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader

simple_transform = transforms.Compose([
  transforms.Resize((64, 64)),
  transforms.ToTensor()
])

# Create datasets
train_dataset = ImageFolder(
    root=train_data_20_percent_path,
    transform=simple_transform,
    target_transform=None
)
test_dataset = ImageFolder(
    root=test_data_20_percent_path,
    transform=simple_transform,
)

# Create dataloaders
train_dataloader = DataLoader(
    train_dataset,
    batch_size=1,
    shuffle=True
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=1,
)

# %%
# Train a model with increased amount of data
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %% [markdown]
# ## 8. Make a prediction on your own custom image of pizza/steak/sushi (you could even download one from the internet) with your trained model from exercise 7 and share your prediction.
# * Does the model you trained in exercise 7 get it right?
# * If not, what do you think you could do to improve it?

# %%
# Train for 50 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params = model.parameters(),
                             lr=0.001)

model_0_results = train(model=model,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=10)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.1232 | train_acc: 0.9778 | test_loss: 4.9491 | test_acc: 0.5333
# Epoch: 2 | train_loss: 0.0795 | train_acc: 0.9733 | test_loss: 4.7469 | test_acc: 0.5467
# Epoch: 3 | train_loss: 0.0670 | train_acc: 0.9844 | test_loss: 4.6335 | test_acc: 0.5333
# Epoch: 4 | train_loss: 0.0013 | train_acc: 1.0000 | test_loss: 4.6411 | test_acc: 0.5400
# Epoch: 5 | train_loss: 0.0008 | train_acc: 1.0000 | test_loss: 4.6635 | test_acc: 0.5400
# Epoch: 6 | train_loss: 0.0006 | train_acc: 1.0000 | test_loss: 4.6997 | test_acc: 0.5400
# Epoch: 7 | train_loss: 0.0005 | train_acc: 1.0000 | test_loss: 4.7434 | test_acc: 0.5400
# Epoch: 8 | train_loss: 0.0004 | train_acc: 1.0000 | test_loss: 4.7871 | test_acc: 0.5400
# Epoch: 9 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.8405 | test_acc: 0.5400
# Epoch: 10 | train_loss: 0.0003 | train_acc: 1.0000 | test_loss: 4.9063 | test_acc: 0.5400
